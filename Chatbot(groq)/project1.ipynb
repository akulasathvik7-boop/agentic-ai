# %% [markdown]
# Project on Chatbot with Groq

# %%
from dotenv import load_dotenv
from langchain_groq import ChatGroq

# Load API Key
load_dotenv()

# Initialize LLM
llm = ChatGroq(
    model="llama-3.1-8b-instant"
)

# %%
# Chat Loop
while True:
    
    user_input = input("You: ")

    if user_input.lower() == "exit":
        print("Goodbye!")
        break

    response = llm.invoke(user_input)

    print("AI:", response.content)
# Out:
# AI: **What is Python?**
#
# Python is a high-level, interpreted programming language that is widely used for various purposes such as:
#
# 1. **Web Development**: Python is used to develop web applications and web services using popular frameworks like Django and Flask.
# 2. **Data Science and Analytics**: Python is a popular language for data analysis, machine learning, and scientific computing due to its extensive libraries like NumPy, pandas, and scikit-learn.
# 3. **Automation**: Python is used to automate tasks and processes, such as data processing, file management, and system administration.
# 4. **Artificial Intelligence and Machine Learning**: Python is used to develop AI and ML models using libraries like TensorFlow and Keras.
# 5. **Education**: Python is a popular teaching language due to its simplicity, readability, and ease of use.
#
# **Key Features of Python:**
#
# 1. **Easy to Learn**: Python has a simple syntax and is relatively easy to learn, even for beginners.
# 2. **Object-Oriented**: Python supports object-oriented programming (OOP) concepts like classes, objects, and inheritance.
# 3. **High-Level**: Python is a high-level language, meaning it abstracts away many low-level details, allowing developers to focus on the logic of the program.
# 4. **Interpreted**: Python code is interpreted at runtime, rather than compiled beforehand, making it easier to write and test code.
# 5. **Cross-Platform**: Python can run on multiple operating systems, including Windows, macOS, and Linux.
#
# **Why Use Python?**
#
# 1. **Rapid Development**: Python's syntax and nature make it ideal for rapid prototyping and development.
# 2. **Large Community**: Python has a large and active community, ensuring there are many resources available for learning and troubleshooting.
# 3. **Extensive Libraries**: Python has a vast collection of libraries and frameworks that make it easy to perform various tasks.
# 4. **Easy to Maintain**: Python code is often easy to read and maintain, due to its simplicity and consistency.
#
# In summary, Python is a versatile, easy-to-learn programming language that is widely used for various purposes, including web development, data science, automation, AI, and more. Its simplicity, readability, and extensive libraries make it an ideal choice for developers and non-developers alike.
# AI: Python is a high-level, interpreted programming language that has gained immense popularity over the years. Here are some reasons that make Python famous:
#
# 1. **Easy to Learn**: Python has a simple syntax and is relatively easy to learn, making it an ideal language for beginners. It's great for teaching programming concepts and is often used in introductory programming courses.
# 2. **Versatility**: Python can be used for a wide range of applications, including:
# 	* Web development (e.g., Django, Flask)
# 	* Data analysis and science (e.g., NumPy, pandas, scikit-learn)
# 	* Artificial intelligence (e.g., TensorFlow, Keras)
# 	* Automation (e.g., scripting, automation of tasks)
# 	* Education (e.g., interactive lessons, games)
# 3. **Large Standard Library**: Python has a vast and comprehensive standard library, which includes modules for various tasks, such as file I/O, networking, security, and more.
# 4. **Cross-Platform**: Python can run on multiple operating systems, including Windows, macOS, and Linux.
# 5. **Large Community**: Python has a massive and active community, which contributes to its popularity. This community creates and shares many resources, libraries, and frameworks.
# 6. **Open-Source**: Python is open-source, which means it's free to use, modify, and distribute. This has contributed to its widespread adoption.
# 7. **Extensive Libraries and Frameworks**: Python has a vast collection of libraries and frameworks that make it easy to perform specific tasks, such as:
# 	* Data analysis: Pandas, NumPy, scikit-learn
# 	* Web development: Django, Flask, Pyramid
# 	* Machine learning: TensorFlow, Keras, scikit-learn
# 	* Automation: PyAutoGUI, Pygame
# 8. **Dynamic Typing**: Python is a dynamically-typed language, which means you don't need to declare the type of a variable before using it.
# 9. **Indentation-Based Syntax**: Python uses indentation to define code blocks, making it easier to read and write.
# 10. **Fast Development**: Python's syntax and nature make it ideal for rapid prototyping and development.
# 11. **Used in Industry**: Python is widely used in various industries, including:
# 	* Scientific computing
# 	* Data analysis
# 	* Finance
# 	* Education
# 	* Gaming
# 	* Web development
#
# These factors have contributed to Python's popularity and have made it one of the most widely used programming languages today.
# AI: It seems like you're looking for an escape. I can provide you with some options depending on what kind of escape you're looking for:
#
# 1. **Escape Room**: An immersive puzzle game where you and your team are "trapped" in a themed room and must solve clues and puzzles to escape within a certain time limit.
#
# 2. **Virtual Escape**: A digital version of an escape room, where you can play online with friends or solo, solving puzzles and escaping virtual rooms.
#
# 3. **Escape from a Problem**: If you're feeling overwhelmed by a personal or professional problem, I can offer suggestions on how to break it down, prioritize tasks, and find a solution.
#
# 4. **Physical Escape**: If you're looking for a physical challenge, I can suggest outdoor activities like hiking, rock climbing, or kayaking that can provide a sense of accomplishment and escape from daily life.
#
# Which type of escape are you looking for?
# AI: It seems like you're looking for a game or a concept. I'll provide a couple of examples.
#
# 1. **Escape Game**: An escape game, also known as an escape room, is a physical adventure game in which players are locked in a themed room and must use clues and solve puzzles to escape within a certain time limit.
#
# 2. **Escape from a Situation**: This can be a metaphor or a real-life situation where someone needs to escape from a difficult or precarious situation. This could be a physical location, an emotional state, or a psychological trap.
#
# 3. **Escape Mechanism**: This can refer to a mechanism or a system that allows something or someone to escape from a confined space or a restrictive situation.
#
# 4. **Escape Room Games Online**: There are also online escape room games where you can play and solve puzzles to escape from a virtual room.
#
# Here are a few examples of online escape room games:
#
# - **The Mysterious Island**: You're stranded on a deserted island and need to find a way to escape.
# - **The Detective's Office**: You're a detective who needs to solve a murder mystery and escape from the office.
# - **The Haunted Mansion**: You're trapped in a haunted mansion and need to find a way to escape before it's too late.
#
# Which one of these examples resonates with you the most, or do you have something else in mind?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 # Chat Loop
#       2 while True:
#       3
# ----> 4     user_input = input("You: ")
#       5
#       6     if user_input.lower() == "exit":
#       7         print("Goodbye!")
#
# File c:\Users\Meridian\OneDrive\Desktop\agentic-ai\.venv\Lib\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File c:\Users\Meridian\OneDrive\Desktop\agentic-ai\.venv\Lib\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
user_input = "What is LangChain?"

response = llm.invoke(user_input)

print(response.content)
# Out:
# LangChain is an open-source framework for building large language models (LLMs) into production-ready applications. It was created by Llama.com and provides a set of tools and libraries that allow developers to integrate LLMs into various use cases, such as chatbots, virtual assistants, and other conversational AI systems.
#
# LangChain is built on top of popular libraries like LangChain, which is a Python framework, and it allows developers to interact with LLMs in a more efficient and scalable way. The framework provides features such as:
#
# 1. **Model management**: LangChain allows developers to easily manage and deploy multiple LLMs, including loading, saving, and versioning models.
# 2. **Prompt engineering**: The framework provides tools for crafting and optimizing prompts to elicit specific responses from LLMs.
# 3. **Chain execution**: LangChain enables developers to create complex workflows and chains of LLMs to perform tasks that require multiple models or steps.
# 4. **Integration with external data**: The framework allows developers to integrate external data sources, such as databases or APIs, to provide context and information to LLMs.
# 5. **Scalability and performance**: LangChain is designed to handle large volumes of requests and responses, making it suitable for production-ready applications.
#
# By providing a set of tools and libraries, LangChain aims to simplify the process of building and deploying LLM-based applications, making it easier for developers to create conversational AI systems that can understand and respond to user input.
#
# In short, LangChain is a powerful framework that helps developers build, deploy, and manage LLMs in production-ready applications, making it easier to create conversational AI systems that can understand and respond to user input.
